# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# ===============================
# Excel-Datei laden
# ===============================
df = pd.read_excel("Wasser + 2,5wt%.xlsx", engine="openpyxl",
                   usecols="A,B", skiprows=3, nrows=589)
df.columns = ["Zeit", "Temperatur"]

# ===============================
# Tangente bei ~500 s berechnen
# ===============================
tangente_df = df[(df["Zeit"] >= 300) & (df["Zeit"] <= 310)]
x_tan = tangente_df["Zeit"].values
y_tan = tangente_df["Temperatur"].values
coeffs = np.polyfit(x_tan, y_tan, deg=1)
m, b = coeffs

# Tangentenlinie berechnen
x_line = np.linspace(200, 450, 200) #x_line = np.linspace(Startwert, Endwert, Punkte)
y_line = m * x_line + b

# ===============================
# Tatsächlichen Schnittpunkt finden
# ===============================
df["Tangente"] = m * df["Zeit"] + b
df["Delta"] = df["Temperatur"] - df["Tangente"]

# Stelle, wo Delta das Vorzeichen wechselt → Schnittpunkt
# Nur Bereich VOR dem Minimum betrachten – also "von oben kommend"
min_index_curve = df["Temperatur"].idxmin()
df_cut = df.iloc[:min_index_curve]

# Vorzeichenwechsel dort suchen
wechsel_idx_array = np.where(np.diff(np.sign(df_cut["Delta"])))[0]

if len(wechsel_idx_array) > 0:
    schnitt_index = wechsel_idx_array[0]
    x_schnitt = df_cut["Zeit"].iloc[schnitt_index]
    y_schnitt = df_cut["Tangente"].iloc[schnitt_index]
else:
    x_schnitt = np.nan
    y_schnitt = np.nan

# ===============================
# Plot erstellen
# ===============================
plt.figure(figsize=(8, 6))

# Originalkurve
plt.plot(df["Zeit"], df["Temperatur"], marker='o', linestyle='-', color='blue', label='Messwerte', linewidth=2)

# Tangente
plt.plot(x_line, y_line, color='red', linestyle='--', linewidth=2,
         label=f"Tangente: y = {m:.3f}x + {b:.2f}")

# Horizontale Linie vom Schnittpunkt zur y-Achse
plt.hlines(y_schnitt, xmin=x_schnitt, xmax=df["Zeit"].max(), color='green',
           linestyle=':', linewidth=2, label=f"Horizontale Linie bei T = {y_schnitt:.2f} °C")

# Schnittpunkt markieren
plt.plot(x_schnitt, y_schnitt, 'ko')  # schwarzer Punkt

# Layout
plt.xlabel("Zeit / s")
plt.ylabel("Temperatur / °C")
plt.title("Abkühlkurve mit Tangente und Schnittpunkt")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
print(f"x_schnitt = {x_schnitt}, y_schnitt = {y_schnitt}")
# Out:
# x_schnitt = nan, y_schnitt = nan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ===============================
# Excel-Datei laden
# ===============================
df = pd.read_excel("Wasser + 2,5wt%.xlsx", engine="openpyxl",
                   usecols="A,B", skiprows=3, nrows=589)
df.columns = ["Zeit", "Temperatur"]

# ===============================
# Tangente bei ~300 s berechnen
# ===============================
# Bereich um die Tangente (angepasst!)
tangente_df = df[(df["Zeit"] >= 315) & (df["Zeit"] <= 380)]
x_tan = tangente_df["Zeit"].values
y_tan = tangente_df["Temperatur"].values
m, b = np.polyfit(x_tan, y_tan, deg=1)

# Tangente berechnen
x_line = np.linspace(200, 450, 200)
y_line = m * x_line + b

# ===============================
# Schnittpunkt mit Abkühlkurve (links der Tangente)
# ===============================
# Tangentenwert zu jedem Zeitpunkt berechnen
df["Tangente"] = m * df["Zeit"] + b
df["Delta"] = df["Temperatur"] - df["Tangente"]

# Suche den ersten echten Vorzeichenwechsel links des Tangentenbereichs
df_links = df[df["Zeit"] < 270]
delta_sign = np.sign(df_links["Delta"])
vorzeichenwechsel = np.where(np.diff(delta_sign))[0]

if len(vorzeichenwechsel) > 0:
    idx = vorzeichenwechsel[-1]  # der letzte Wechsel vor t=300
    # lineare Interpolation zwischen den beiden Punkten
    x1, x2 = df_links["Zeit"].iloc[idx], df_links["Zeit"].iloc[idx + 1]
    y1, y2 = df_links["Temperatur"].iloc[idx], df_links["Temperatur"].iloc[idx + 1]
    t1, t2 = df_links["Tangente"].iloc[idx], df_links["Tangente"].iloc[idx + 1]

    # Interpolierter Schnittpunkt (Temperatur = Tangente)
    delta1 = y1 - t1
    delta2 = y2 - t2
    x_schnitt = x1 - delta1 * (x2 - x1) / (delta2 - delta1)
    y_schnitt = m * x_schnitt + b
else:
    x_schnitt = np.nan
    y_schnitt = np.nan

# ===============================
# Plot
# ===============================
plt.figure(figsize=(8, 6))

# Originalkurve
plt.plot(df["Zeit"], df["Temperatur"], color='blue', linewidth=2, label='Messwerte')

# Tangente
plt.plot(x_line, y_line, color='red', linestyle='--', linewidth=2,
         label=f"Tangente: y = {m:.3f}x + {b:.2f}")

# Horizontale ab Schnittpunkt
if not np.isnan(x_schnitt):
    plt.hlines(y_schnitt, xmin=0, xmax=x_schnitt, color='green', linestyle=':', linewidth=2,
           label = fr"$T_{{\mathrm{{Gefrierpunkt}}}} = {y_schnitt:.2f}\,^{{\circ}}\mathrm{{C}}$")
    plt.plot(x_schnitt, y_schnitt, 'ko', label="Gefrierpunkt")  # Punkt markieren

# Layout
plt.xlabel("Zeit / s")
plt.ylabel("Temperatur / °C")
plt.title("Graph 4: Abkühlkurve mit Tangente und Schnittpunkt")
plt.grid(True)
plt.legend()
plt.tight_layout()

# Y-Achsenbereich ausgeben
y_limits = plt.ylim(-5, 5)
print(f"Y-Achse reicht von {y_limits[0]:.2f} bis {y_limits[1]:.2f} °C")

x_limits = plt.xlim(200, 400)
print(f"X-Achse reicht von {x_limits[0]:.2f} bis {x_limits[1]:.2f} °C")

plt.show()
# Out:
# Y-Achse reicht von -5.00 bis 5.00 °C
# X-Achse reicht von 200.00 bis 400.00 °C

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# ===============================
# Excel-Datei laden
# ===============================
df = pd.read_excel("Wasser + 2,5wt%.xlsx", engine="openpyxl",
                   usecols="A,B", skiprows=3, nrows=589)
df.columns = ["Zeit", "Temperatur"]

# ===============================
# Tangente (Fit) im Bereich 315–380 s
# ===============================
fit_mask = (df["Zeit"] >= 315) & (df["Zeit"] <= 380)
x_tan = df.loc[fit_mask, "Zeit"].values
y_tan = df.loc[fit_mask, "Temperatur"].values

def lin(x, m, b):
    return m * x + b

popt, pcov = curve_fit(lin, x_tan, y_tan)
m, b = popt
σ_m, σ_b = np.sqrt(np.diag(pcov))
cov_mb = pcov[0, 1]

# R² berechnen
y_pred = lin(x_tan, *popt)
ss_res = np.sum((y_tan - y_pred)**2)
ss_tot = np.sum((y_tan - np.mean(y_tan))**2)
r2 = 1 - ss_res / ss_tot

# ===============================
# Schnittpunkt links von t ≈ 300 s
# ===============================
df["Tangente"] = lin(df["Zeit"], *popt)
df["Delta"] = df["Temperatur"] - df["Tangente"]

df_links = df[df["Zeit"] < 270]
delta_sign = np.sign(df_links["Delta"])
vorzeichenwechsel = np.where(np.diff(delta_sign))[0]

if len(vorzeichenwechsel) > 0:
    idx = vorzeichenwechsel[-1]
    x1, x2 = df_links["Zeit"].iloc[idx], df_links["Zeit"].iloc[idx + 1]
    y1, y2 = df_links["Temperatur"].iloc[idx], df_links["Temperatur"].iloc[idx + 1]
    t1, t2 = df_links["Tangente"].iloc[idx], df_links["Tangente"].iloc[idx + 1]

    delta1 = y1 - t1
    delta2 = y2 - t2
    x_schnitt = x1 - delta1 * (x2 - x1) / (delta2 - delta1)
    y_schnitt = lin(x_schnitt, *popt)

    # Standardfehler des Gefrierpunkts
    σ_T = np.sqrt(x_schnitt**2 * σ_m**2 + σ_b**2 + 2 * x_schnitt * cov_mb)
else:
    x_schnitt = np.nan
    y_schnitt = np.nan
    σ_T = np.nan

# ===============================
# Plot
# ===============================
plt.figure(figsize=(8, 6))
plt.plot(df["Zeit"], df["Temperatur"], color='blue', linewidth=2, label='Messwerte')

x_line = np.linspace(200, 450, 200)
plt.plot(x_line, lin(x_line, *popt), color='red', linestyle='--', linewidth=2,
         label=f"Tangente: y = {m:.3f}x + {b:.2f}")

if not np.isnan(x_schnitt):
    plt.hlines(y_schnitt, xmin=0, xmax=x_schnitt, color='green', linestyle=':', linewidth=2,
           label = fr"$T_{{\mathrm{{Gefrierpunkt}}}} = {y_schnitt:.2f} \pm {σ_T:.2f}\,^{{\circ}}\mathrm{{C}}$")
    plt.plot(x_schnitt, y_schnitt, 'ko', label="Gefrierpunkt")

# Layout
plt.xlabel("Zeit / s")
plt.ylabel("Temperatur / °C")
plt.title("Graph 4: Abkühlkurve mit Tangente und Gefrierpunkt")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.ylim(-5, 5)
plt.xlim(200, 400)
plt.show()

# ===============================
# Ausgabe in Konsole
# ===============================
print(f"R² der Tangente           : {r2:.4f}")
print(f"Gefrierpunkt              : {y_schnitt:.2f} ± {σ_T:.2f} °C (1 σ)")
print(f"Standardfehler (1 σ)      : ±{σ_T:.2f} °C")
print(f"Fit-Parameter             : m = {m:.5f} ± {σ_m:.5f},   b = {b:.2f} ± {σ_b:.2f}")
# Out:
# R² der Tangente           : 0.0654
# Gefrierpunkt              : -0.23 ± 0.01 °C (1 σ)
# Standardfehler (1 σ)      : ±0.01 °C
# Fit-Parameter             : m = -0.00022 ± 0.00011,   b = -0.17 ± 0.04
