# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ===============================
# Daten einlesen
# ===============================
df = pd.read_excel("Exp2-3_p(x)_T(x)_Template2025Kopie.xlsx", engine="openpyxl",
                   usecols="X,Y", skiprows=7, nrows=7)
df.columns = ["F_A","F_B"]

# ===============================
# Plot erstellen
# ===============================
plt.figure(figsize=(8, 6))

# ln(y_A) vs. x_B
plt.plot(df["F_B"], df["F_A"], marker='o', color='blue')

# Achsen & Layout
plt.xlabel("F_B")
plt.ylabel("F_B")
plt.title("Kalibirergerade")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/hd/f5n6dywd28bgfnhwhdf_g_pw0000gn/T/ipykernel_58324/2854867207.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
print(df.head(9))
# Out:
#         F_A       F_B
# 0   43.0668  363.6958
# 1   77.7046  338.0513
# 2  122.7308  297.7757
# 3  160.3857  259.1726
# 4  219.5443  211.1145
# 5  268.6722  135.3379
# 6  360.3306   62.1712

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ===============================
# Daten einlesen
# ===============================
df = pd.read_excel("Exp2-3_p(x)_T(x)_Template2025Kopie.xlsx", engine="openpyxl",
                   usecols="X,Y", skiprows=7, nrows=7)
df.columns = ["F_A", "F_B"]

# ===============================
# Lineare Regression (y = m*x + b)
# ===============================
x = df["F_B"]
y = df["F_A"]

# Fit durchführen
coeffs = np.polyfit(x, y, deg=1)      # Grad 1 = gerade
fit_func = np.poly1d(coeffs)

# Für die Darstellung: Fit-Linie berechnen
x_fit = np.linspace(x.min(), x.max(), 100)
y_fit = fit_func(x_fit)

# ===============================
# Plot erstellen
# ===============================
plt.figure(figsize=(8, 6))

# Messpunkte
plt.scatter(x, y, color='blue', label="Messpunkte")

# Fit-Linie
plt.plot(x_fit, y_fit, color='red', linestyle='--', label=f"Fit: y = {coeffs[0]:.3f}x + {coeffs[1]:.3f}")

# Achsen & Layout
plt.xlabel("F_B")
plt.ylabel("F_A")
plt.title("Kalibriergerade")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ===============================
# Daten einlesen
# ===============================
df = pd.read_excel("Exp2-3_p(x)_T(x)_Template2025Kopie.xlsx", engine="openpyxl",
                   usecols="X,Y", skiprows=7, nrows=7)
df.columns = ["F_A", "F_B"]

# Beispielhafte Fehlerwerte (ersetzen durch echte, falls vorhanden)
df["F_A_err"] = 0.05  # Konstanter Fehler von 0.05 – kannst du durch echte Werte ersetzen

# ===============================
# Lineare Regression (y = m*x + b)
# ===============================
x = df["F_B"]
y = df["F_A"]
y_err = df["F_A_err"]

coeffs = np.polyfit(x, y, deg=1)
fit_func = np.poly1d(coeffs)

x_fit = np.linspace(x.min(), x.max(), 100)
y_fit = fit_func(x_fit)

# ===============================
# Plot mit Fehlerbalken
# ===============================
plt.figure(figsize=(8, 6))

# Messpunkte mit Fehlerbalken
plt.errorbar(x, y, yerr=y_err, fmt='o', color='yellow', label="Messpunkte mit Fehler")

# Fit-Linie
plt.plot(x_fit, y_fit, color='red', linestyle='--',
         label=f"Fit: y = {coeffs[0]:.3f}x + {coeffs[1]:.3f}")

# Achsen & Layout
plt.xlabel("F_B")
plt.ylabel("F_A")
plt.title("Kalibriergerade mit Fehlerbalken")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ===============================
# Daten einlesen
# ===============================
df = pd.read_excel("Exp2-3_p(x)_T(x)_Template2025Kopie.xlsx", engine="openpyxl",
                   usecols="X,Y", skiprows=7, nrows=7)
df.columns = ["F_A", "F_B"]

# Beispielhafte Fehlerwerte (ersetzen durch echte, falls vorhanden)
df["F_A_err"] = 0.05  # Konstanter Fehler von 0.05 – kannst du durch echte Werte ersetzen

# ===============================
# Lineare Regression (y = m*x + b)
# ===============================
x = df["F_B"]
y = df["F_A"]
y_err = df["F_A_err"]

coeffs = np.polyfit(x, y, deg=1)
fit_func = np.poly1d(coeffs)

x_fit = np.linspace(x.min(), x.max(), 100)
y_fit = fit_func(x_fit)

# ===============================
# Plot mit Fehlerbalken
# ===============================
plt.figure(figsize=(8, 6))

# Messpunkte mit Fehlerbalken
plt.errorbar(x, y, yerr=y_err, fmt='o', color='yellow', label="Messpunkte mit Fehler")

# Fit-Linie
plt.plot(x_fit, y_fit, color='red', linestyle='--',
         label=f"Fit: y = {coeffs[0]:.3f}x + {coeffs[1]:.3f}")

# Achsen & Layout
plt.xlabel("F_B")
plt.ylabel("F_A")
plt.title("Kalibriergerade mit Fehlerbalken")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# ===============================
# Daten einlesen
# ===============================
df = pd.read_excel("Exp2-3_p(x)_T(x)_Template2025Kopie.xlsx", engine="openpyxl",
                   usecols="X,Y", skiprows=7, nrows=7)
df.columns = ["F_A", "F_B"]

# Beispielhafte Fehlerwerte (konstanter Fehler)
df["F_A_err"] = 0.05  # Ersetze durch echte Fehler, falls vorhanden

# ===============================
# Werte vorbereiten
# ===============================
x = df["F_B"]
y = df["F_A"]
y_err = df["F_A_err"]

# ===============================
# Lineare Funktion für Fit
# ===============================
def lin_func(x, m, b):
    return m * x + b

# Fit mit Fehlern
popt, pcov = curve_fit(lin_func, x, y, sigma=y_err, absolute_sigma=True)
m, b = popt
m_err, b_err = np.sqrt(np.diag(pcov))

# Fit-Kurve erzeugen
x_fit = np.linspace(x.min(), x.max(), 100)
y_fit = lin_func(x_fit, m, b)

# ===============================
# Plot erstellen
# ===============================
plt.figure(figsize=(8, 6))

# Messpunkte mit Fehlerbalken
plt.errorbar(x, y, yerr=y_err, fmt='o', color='yellow', label="Messpunkte mit Fehler")

# Fit-Linie mit Gleichung und Fehlern
plt.plot(x_fit, y_fit, color='red', linestyle='--',
         label=f"Fit: y = ({m:.3f}±{m_err:.3f})x + ({b:.3f}±{b_err:.3f})")

# Achsen & Layout
plt.xlabel("F_B")
plt.ylabel("F_A")
plt.title("Kalibriergerade mit Fehlerbalken und Parameterunsicherheiten")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# ===============================
# Daten einlesen
# ===============================
df = pd.read_excel("Exp2-3_p(x)_T(x)_Template2025Kopie.xlsx", engine="openpyxl",
                   usecols="Z,AA", skiprows=7, nrows=7)
df.columns = ["x_A/x_B", "F_A/F_B"]

# Beispielhafte Fehlerwerte (konstanter Fehler)
df["x_A/x_B_err"] = 0.05  # Ersetze durch echte Fehler, falls vorhanden

# ===============================
# Werte vorbereiten
# ===============================
x = df["x_A/x_B"]
y = df["F_A/F_B"]
y_err = df["F_A/F_B_err"]

# ===============================
# Lineare Funktion für Fit
# ===============================
def lin_func(x, m, b):
    return m * x + b

# Fit mit Fehlern
popt, pcov = curve_fit(lin_func, x, y, sigma=y_err, absolute_sigma=True)
m, b = popt
m_err, b_err = np.sqrt(np.diag(pcov))

# Fit-Kurve erzeugen
x_fit = np.linspace(x.min(), x.max(), 100)
y_fit = lin_func(x_fit, m, b)

# ===============================
# Plot erstellen
# ===============================
plt.figure(figsize=(8, 6))

# Messpunkte mit Fehlerbalken
plt.errorbar(x, y, yerr=y_err, fmt='o', color='yellow', label="Messpunkte mit Fehler")

# Fit-Linie mit Gleichung und Fehlern
plt.plot(x_fit, y_fit, color='red', linestyle='--',
         label=f"Fit: y = ({m:.3f}±{m_err:.3f})x + ({b:.3f}±{b_err:.3f})")

# Achsen & Layout
plt.xlabel("x_A/x_B")
plt.ylabel("F_A/F_B")
plt.title("Kalibriergerade mit Fehlerbalken und Parameterunsicherheiten")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PyCharmMiscProject/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'F_A/F_B_err'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 21
#      19 x = df["x_A/x_B"]
#      20 y = df["F_A/F_B"]
# ...

# %%
print(df.columns)
# Out:
# Index(['x_A/x_B', 'F_A/F_B', 'x_A/x_B_err'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# ===============================
# Excel-Daten einlesen
# ===============================
df = pd.read_excel("Exp2-3_p(x)_T(x)_Template2025Kopie.xlsx",
                   engine="openpyxl",
                   usecols="Z,AA",  # Passe an, falls andere Spalten
                   skiprows=7,
                   nrows=7)

# Spalten benennen
df.columns = ["x_ratio", "F_ratio"]

# Fehler abschätzen (hier z. B. 5 % des y-Werts)
df["F_ratio_err"] = df["F_ratio"] * 0.05  # oder konstant z. B. 0.05

# ===============================
# Daten vorbereiten
# ===============================
x = df["x_ratio"].values
y = df["F_ratio"].values
y_err = df["F_ratio_err"].values

# ===============================
# Lineare Fit-Funktion
# ===============================
def lin_func(x, m, b):
    return m * x + b

# ===============================
# Fit ausführen mit Fehlern
# ===============================
popt, pcov = curve_fit(lin_func, x, y, sigma=y_err, absolute_sigma=True)
m, b = popt
m_err, b_err = np.sqrt(np.diag(pcov))

# Fit-Kurve berechnen
x_fit = np.linspace(min(x), max(x), 200)
y_fit = lin_func(x_fit, m, b)

# ===============================
# Plot erstellen
# ===============================
plt.figure(figsize=(8, 6))
plt.errorbar(x, y, yerr=y_err, fmt='o', color='black', label="Messpunkte mit Fehler")
plt.plot(x_fit, y_fit, 'r--', label=f"Fit: y = ({m:.3f}±{m_err:.3f})x + ({b:.3f}±{b_err:.3f})")

plt.xlabel(r"Molenbruch-Verhältnis $x_A/x_B$")
plt.ylabel(r"Peakflächen-Verhältnis $F_A/F_B$")
plt.title("Kalibriergerade zur GC-Auswertung")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ===============================
# Ergebnisse ausgeben
# ===============================
print(f"Steigung m = {m:.4f} ± {m_err:.4f}")
print(f"y-Achsenabschnitt b = {b:.4f} ± {b_err:.4f}")
# Out:
# Steigung m = 1.2343 ± 0.0316
# y-Achsenabschnitt b = 0.0148 ± 0.0112

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# ===============================
# Excel-Daten einlesen
# ===============================
df = pd.read_excel("Exp2-3_p(x)_T(x)_Template2025Kopie.xlsx",
                   engine="openpyxl",
                   usecols="Z,AA",
                   skiprows=7,
                   nrows=7)

df.columns = ["x_ratio", "F_ratio"]
df["F_ratio_err"] = df["F_ratio"] * 0.05

# ===============================
# Funktion für Plot und Fit
# ===============================
def fit_and_plot(df_section, title_suffix):
    x = df_section["x_ratio"].values
    y = df_section["F_ratio"].values
    y_err = df_section["F_ratio_err"].values

    # Lineare Funktion
    def lin_func(x, m, b):
        return m * x + b

    # Fit
    popt, pcov = curve_fit(lin_func, x, y, sigma=y_err, absolute_sigma=True)
    m, b = popt
    m_err, b_err = np.sqrt(np.diag(pcov))

    # Fit-Kurve
    x_fit = np.linspace(min(x), max(x), 200)
    y_fit = lin_func(x_fit, m, b)

    # Plot
    plt.figure(figsize=(8, 6))
    plt.errorbar(x, y, yerr=y_err, fmt='o', color='black', label="Messpunkte mit Fehler")
    plt.plot(x_fit, y_fit, 'r--',
             label=f"Fit: y = ({m:.3f}±{m_err:.3f})x + ({b:.3f}±{b_err:.3f})")

    plt.xlabel(r"Molenbruch-Verhältnis $x_A/x_B$")
    plt.ylabel(r"Peakflächen-Verhältnis $F_A/F_B$")
    plt.title(f"Kalibriergerade ({title_suffix})")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Ausgabe
    print(f"--- Bereich: {title_suffix} ---")
    print(f"Steigung m = {m:.4f} ± {m_err:.4f}")
    print(f"y-Achsenabschnitt b = {b:.4f} ± {b_err:.4f}")
    print()

# ===============================
# Daten aufteilen und Plotten
# ===============================
df_low = df[df["x_ratio"] < 0.5]
df_high = df[df["x_ratio"] > 0.5]

fit_and_plot(df_low, "x_A/x_B < 0,5")
fit_and_plot(df_high, "x_A/x_B > 0,5")
# Out:
# --- Bereich: x_A/x_B < 0,5 ---
# Steigung m = 1.1679 ± 0.1207
# y-Achsenabschnitt b = 0.0275 ± 0.0231
# --- Bereich: x_A/x_B > 0,5 ---
# Steigung m = 1.2641 ± 0.0484
# y-Achsenabschnitt b = -0.0219 ± 0.0521

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# ===============================
# Excel-Daten einlesen
# ===============================
df = pd.read_excel("Exp2-3_p(x)_T(x)_Template2025Kopie.xlsx",
                   engine="openpyxl",
                   usecols="AB,AC",
                   skiprows=7,
                   nrows=7)

df.columns = ["x_ratio", "F_ratio"]
df["F_ratio_err"] = df["F_ratio"] * 0.05

# ===============================
# Funktion für Plot und Fit
# ===============================
def fit_and_plot(df_section, title_suffix):
    x = df_section["x_ratio"].values
    y = df_section["F_ratio"].values
    y_err = df_section["F_ratio_err"].values

    # Lineare Funktion
    def lin_func(x, m, b):
        return m * x + b

    # Fit
    popt, pcov = curve_fit(lin_func, x, y, sigma=y_err, absolute_sigma=True)
    m, b = popt
    m_err, b_err = np.sqrt(np.diag(pcov))

    # Fit-Kurve
    x_fit = np.linspace(min(x), max(x), 200)
    y_fit = lin_func(x_fit, m, b)

    # Plot
    plt.figure(figsize=(8, 6))
    plt.errorbar(x, y, yerr=y_err, fmt='o', color='black', label="Messpunkte mit Fehler")
    plt.plot(x_fit, y_fit, 'r--',
             label=f"Fit: y = ({m:.3f}±{m_err:.3f})x + ({b:.3f}±{b_err:.3f})")

    plt.xlabel(r"Molenbruch-Verhältnis $x_B/x_A$")
    plt.ylabel(r"Peakflächen-Verhältnis $F_B/F_A$")
    plt.title(f"Kalibriergerade ({title_suffix})")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Ausgabe
    print(f"--- Bereich: {title_suffix} ---")
    print(f"Steigung m = {m:.4f} ± {m_err:.4f}")
    print(f"y-Achsenabschnitt b = {b:.4f} ± {b_err:.4f}")
    print()

# ===============================
# Daten aufteilen und Plotten
# ===============================
df_low = df[df["x_ratio"] < 0.5]
df_high = df[df["x_ratio"] > 0.5]

fit_and_plot(df_low, "x_B/x_A < 0,5")
fit_and_plot(df_high, "x_B/x_A > 0,5")
# Out:
# --- Bereich: x_B/x_A < 0,5 ---
# Steigung m = 0.8965 ± 0.0779
# y-Achsenabschnitt b = -0.0218 ± 0.0139
# --- Bereich: x_B/x_A > 0,5 ---
# Steigung m = 0.7612 ± 0.0294
# y-Achsenabschnitt b = 0.0403 ± 0.0327
